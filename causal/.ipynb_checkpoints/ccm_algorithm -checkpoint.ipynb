# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import sklearn
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ## Create lorentz time series

# %%
# Parameters
T=1000 #sequence size
sigma=10
beta=8/3
rho=28
dt=0.01

# %%
x=np.zeros((T+1))
y=np.zeros((T+1))
z=np.zeros((T+1))
x[0]=0.2*(np.random.rand()-0.5)
y[0]=0.2*(np.random.rand()-0.5)
z[0]=0.2*(np.random.rand()-0.5)

for i in range(T):
    x[i+1]=x[i]+dt*sigma*(y[i]-x[i])
    y[i+1]=y[i]+dt*(x[i]*(rho-z[i])-y[i])
    z[i+1]=z[i]+dt*(x[i]*y[i]-beta*z[i])

fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot(x)
ax.plot(y)
ax.plot(z)

fig2=plt.figure()
ax2=fig2.add_subplot(111,projection='3d')
ax2.plot(x,y,z)

# %% [markdown]
# ### Create shadow manifold for X,Y and Z

# %%
E=3
tau=1
L=20 # number of samples from the time series sequence

# %%
shadow_x=[]
idx=np.random.randint(1,T,L)
for i in idx:
    sample=[x[i],x[i-tau],x[i-2*tau]]
    shadow_x.append(sample)

# %%
idx
# Out:
# array([419, 718,  70, 698,  54, 681, 983, 427, 922, 658, 912, 260, 948,
#        923, 750, 573, 668, 524, 638, 741])

# %%
shadow_y=np.zeros((T-E+2,E))
shadow_y[:,0]=np.transpose(y[2:])
shadow_y[:,1]=np.transpose(y[1:-1])
shadow_y[:,2]=np.transpose(y[:-2])

# %% [markdown]
# ### Find E+1 nearest neighbors

# %%
nbrs=NearestNeighbors(n_neighbors=E+1,algorithm='ball_tree').fit(shadow_x)
distances, indices=nbrs.kneighbors(shadow_x)

# the first index is the point itself at distance 0

# %%
for i in range(len(indices)):
    for j in range(len(indices[i])):
        indices[i,j]=idx[indices[i,j]]
# translate indices to time indices

# %% [markdown]
# ### Compute predicted values

# %%
distances
# Out:
# array([[ 0.        ,  0.88555169,  2.61271495,  3.48971549],
#        [ 0.        ,  0.1377731 ,  0.9770402 ,  2.61637439],
#        [ 0.        , 13.34553425, 19.82060813, 23.73688877],
#        [ 0.        ,  2.28711507,  3.13684317,  3.5998482 ],
#        [ 0.        ,  1.40962171,  1.79605652,  2.45690705],
#        [ 0.        ,  1.35260065,  1.42228074,  3.5998482 ],
#        [ 0.        ,  0.88555169,  3.37711469,  4.36502374],
#        [ 0.        ,  0.40211357,  1.40962171,  3.14323889],
#        [ 0.        ,  0.90196915,  0.9770402 ,  2.09749852],
#        [ 0.        ,  6.57125113, 10.46026202, 10.85679648],
#        [ 0.        ,  3.88345015,  6.12162097,  6.36577363],
#        [ 0.        ,  1.42228074,  1.73275451,  2.28711507],
#        [ 0.        ,  2.09749852,  2.19576718,  2.4792532 ],
#        [ 0.        ,  0.1377731 ,  0.90196915,  2.4792532 ],
#        [ 0.        ,  1.35260065,  1.73275451,  3.13684317],
#        [ 0.        ,  3.91648552,  4.31754289,  5.69450982],
#        [ 0.        ,  2.45690705,  2.61271495,  3.14323889],
#        [ 0.        , 12.219804  , 12.99599722, 13.04609383],
#        [ 0.        ,  0.40211357,  1.79605652,  3.49504874],
#        [ 0.        ,  2.19576718,  2.59962283,  2.69767469]])

# %%
# compute weights

weights_u=np.zeros((L,E))
for i in range(L):
    for j in range(1,E+1):
        weights_u[i,j-1]= np.exp(-distances[i,j]/distances[i,1])

# %%
weights_u
# Out:
# array([[3.67879441e-01, 5.23197648e-02, 1.94341244e-02],
#        [3.67879441e-01, 8.32013740e-04, 5.65650937e-09],
#        [3.67879441e-01, 2.26460088e-01, 1.68867806e-01],
#        [3.67879441e-01, 2.53718891e-01, 2.07221090e-01],
#        [3.67879441e-01, 2.79671163e-01, 1.75002523e-01],
#        [3.67879441e-01, 3.49407770e-01, 6.98484604e-02],
#        [3.67879441e-01, 2.20692182e-02, 7.23259441e-03],
#        [3.67879441e-01, 3.00308135e-02, 4.02911409e-04],
#        [3.67879441e-01, 3.38500342e-01, 9.77378953e-02],
#        [3.67879441e-01, 2.03554400e-01, 1.91634414e-01],
#        [3.67879441e-01, 2.06731245e-01, 1.94134182e-01],
#        [3.67879441e-01, 2.95734587e-01, 2.00275447e-01],
#        [3.67879441e-01, 3.51041648e-01, 3.06663342e-01],
#        [3.67879441e-01, 1.43473865e-03, 1.53034030e-08],
#        [3.67879441e-01, 2.77744394e-01, 9.83601073e-02],
#        [3.67879441e-01, 3.32072366e-01, 2.33637468e-01],
#        [3.67879441e-01, 3.45274241e-01, 2.78218666e-01],
#        [3.67879441e-01, 3.45238676e-01, 3.43826225e-01],
#        [3.67879441e-01, 1.14869874e-02, 1.67974972e-04],
#        [3.67879441e-01, 3.06075149e-01, 2.92708056e-01]])

# %%
weights_w=np.zeros((L,E))
for i in range(L): 
    weights_w[i,:]=weights_u[i,:]/(sum(weights_u[i,:]))

# %%
# check is sum is 1
boole=True 
for i in range(L):
    boole=boole&(sum(weights_w[i,:])-1.0<0.000001)
print (boole)
# Out:
# True

# %%
shadow_y_pred=np.zeros((L,E))
for i in range(L):
    # for each point in the shadow manifold
    for j in range(1,E+1):
            shadow_y_pred[i,:]=shadow_y_pred[i,:]+weights_w[i,j-1]*shadow_y[indices[i,j],:]

# %%
shadow_y_pred
# Out:
# array([[ -7.48499322,  -6.96942373,  -6.49628817],
#        [ 16.28473273,  15.59081739,  14.85813678],
#        [ -9.18587447,  -9.66119533, -10.16535193],
#        [  1.14512522,   1.13209017,   1.12832193],
#        [-10.64282563, -10.11714445,  -9.6034474 ],
#        [  0.17852952,   0.13342198,   0.09540877],
#        [ -8.38114716,  -7.86833141,  -7.39037328],
#        [-14.64609067, -13.87832212, -13.11210311],
#        [ 14.62155414,  13.96461887,  13.28949358],
#        [-14.1328395 , -13.70104455, -13.23380364],
#        [  2.81753176,   2.75141742,   2.73409941],
#        [ -0.06403329,  -0.15311598,  -0.23354957],
#        [  8.73328049,   8.42876731,   8.17470152],
#        [ 17.80925549,  16.91779858,  15.98930294],
#        [  3.48078755,   3.44010143,   3.41616041],
#        [-15.29476018, -14.35620971, -13.43871711],
#        [-13.93385104, -12.93498647, -11.98208063],
#        [  9.35920509,   9.0106597 ,   8.70789182],
#        [-14.08014843, -13.3608929 , -12.64409514],
#        [  9.5190019 ,   9.1419539 ,   8.78892209]])

# %%
shadow_y_target=[]
for i in idx:
    sample=[x[i],x[i-tau],x[i-2*tau]]
    shadow_y_target.append(sample)

# %%
shadow_y_target
# Out:
# [[-4.891330234300252, -4.620527985356918, -4.367585316365938],
#  [9.329037476558991, 8.692895682943709, 8.0901444193368],
#  [-21.014879263043113, -21.46302277424181, -21.471628005399594],
#  [2.251399039829937, 2.1101028918768723, 1.9784394654768347],
#  [-7.326710505078405, -6.585125224083547, -5.912705003272894],
#  [0.22845236005185185, 0.04341728972508155, -0.16524996735656824],
#  [-4.373325760090215, -4.108917717762662, -3.8634741171173688],
#  [-7.833491004951878, -7.383747612190299, -6.957888806350636],
#  [8.659752215450233, 8.13876448048984, 7.643374447178681],
#  [-13.113241528142177, -13.653089236398316, -14.077553109808404],
#  [4.619452831730825, 4.346660934920233, 4.092987753036555],
#  [1.294758165117633, 0.8419286384502087, 0.33300102396203657],
#  [6.955473745341993, 7.88693332605801, 8.839834236699376],
#  [9.204462088566794, 8.659752215450233, 8.13876448048984],
#  [-0.2095997480826315, 0.39235639693022006, 1.0659609633705598],
#  [-10.242974504833281, -9.884689636130833, -9.523206501466328],
#  [-5.101850750632669, -5.857685809971246, -6.6591788770917235],
#  [15.764826819676827, 16.229941466736673, 16.496659761417835],
#  [-8.077885375276349, -7.615478917086917, -7.177587050121516],
#  [7.93213985265169, 9.142018437843223, 10.35386138251986]]

# %% [markdown]
# ### Compute correlation between predicted and target

# %%
Compute the mean values and standard deviation,
